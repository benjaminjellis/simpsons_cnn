# %%
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()
# Out:
#      |████████████████████████████████| 727kB 14.7MB/s
#      |████████████████████████████████| 1.1MB 50.6MB/s
#      |████████████████████████████████| 51kB 8.8MB/s
#      |████████████████████████████████| 51kB 9.4MB/s
#      |████████████████████████████████| 194kB 50.7MB/s
#      |████████████████████████████████| 40kB 5.7MB/s
#      |████████████████████████████████| 92kB 13.7MB/s
#      |████████████████████████████████| 51kB 8.5MB/s
#      |████████████████████████████████| 61kB 10.8MB/s
#      |████████████████████████████████| 51kB 9.8MB/s
#      |████████████████████████████████| 2.6MB 56.4MB/s
# Mounted at /content/gdrive

# %% [markdown]
# Import fast.ai vision libraries

# %%
from fastbook import *
from fastai.vision.all import *

# %% [markdown]
# Connect to google drive to get dataset

# %%
data_dir = "/content/gdrive/My Drive/simpsons"

# %% [markdown]
# Load in our dataset, using 20% as a vlidation dataset, a random seed of 10, batch sizes of 32 and resizing each image to be (160,160)

# %%
dataset = ImageDataLoaders.from_folder(data_dir, valid_pct = 0.2, seed = 10,bs= 32, item_tfms= Resize(160))

# %% [markdown]
# Picking resnet50 and using accuracy as our metric of choice

# %%
learn = cnn_learner(dataset, resnet50, metrics=accuracy)

# %% [markdown]
# Find a good learning rate

# %%
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=0.006918309628963471, lr_steep=0.009120108559727669)

# %% [markdown]
# Fit the resnet50 model using the above learning rate for 15 epochs

# %%
learn.fit(n_epoch= 15, lr = 0.007)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.777393</td>
#       <td>0.698830</td>
#       <td>0.828954</td>
#       <td>02:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.558413</td>
#       <td>0.467578</td>
#       <td>0.881988</td>
#       <td>02:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.537470</td>
#       <td>0.470816</td>
#       <td>0.880076</td>
#       <td>02:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.440765</td>
#       <td>0.318082</td>
#       <td>0.920449</td>
#       <td>02:16</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.364705</td>
#       <td>0.329879</td>
#       <td>0.920688</td>
#       <td>02:16</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %% [markdown]
# We get an accuracy of ~94% which is pretty good for so few lines of code!

# %%
learn.export(fname="/content/gdrive/My Drive/simpsons_cnn_fast_ai_v1.pkl")

# %% [markdown]
# Take a look at some predictions to see what the model is predicting

# %%
learn.show_results()
